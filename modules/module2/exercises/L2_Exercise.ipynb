# %% [markdown]
# # Module 2 Color Exercise
#
# **For the exercises, we will create plots with correct and adequate color schemes similar to the lab and practice.**

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1:** Display colormaps with 7 colors from RColorBrewer library for a **sequential** data type with **colorblind safe** colors.

# %%
## Your answer for activity 1 goes here ---
display.brewer.all(n = 7, type = 'seq', colorblindFriendly = T)
# Out:
# plot without title

# %% [markdown]
# **Activity 2:** Create a **colorblind safe colormap with 100 colors** from the dichromat library, and display their hexadecimal codes.

# %%
library(dichromat)
## Your answer for activity 2 goes here ---
p <- colorRampPalette(colorschemes$GreentoMagenta.16)(100)
p
# Out:
#   [1] "#005100" "#005900" "#006100" "#006900" "#007100" "#007900" "#008100"
#   [8] "#008900" "#009100" "#009900" "#00A100" "#00AA00" "#00B200" "#00BA00"
#  [15] "#00C200" "#00CA00" "#00D200" "#00DA00" "#00E200" "#00EA00" "#02F102"
#  [22] "#0EF30E" "#1BF51B" "#27F727" "#33F933" "#3FFC3F" "#4CFE4C" "#55FF55"
#  [29] "#5DFF5D" "#65FF65" "#6DFF6D" "#75FF75" "#7DFF7D" "#86FF86" "#8EFF8E"
#  [36] "#96FF96" "#9EFF9E" "#A6FFA6" "#AEFFAE" "#B7FFB7" "#C0FFC0" "#CAFFCA"
#  [43] "#D4FFD4" "#DEFFDE" "#E8FFE8" "#F2FFF2" "#FCFFFC" "#FFFDFF" "#FFFBFF"
#  [50] "#FFF9FF" "#FFF6FF" "#FFF4FF" "#FFF2FF" "#FFEFFF" "#FFE7FF" "#FFDFFF"
#  [57] "#FFD7FF" "#FFCFFF" "#FFC7FF" "#FFBFFF" "#FFB7FF" "#FFAEFF" "#FFA6FF"
#  [64] "#FF9EFF" "#FF96FF" "#FF8EFF" "#FF85FF" "#FF7DFF" "#FF75FF" "#FF6DFF"
#  [71] "#FF65FF" "#FF5DFF" "#FF55FF" "#FE4CFE" "#FC3FFC" "#F933F9" "#F727F7"
#  [78] "#F51BF5" "#F30EF3" "#F102F1" "#EA00EA" "#E200E2" "#DA00DA" "#D200D2"
#  [85] "#CA00CA" "#C200C2" "#BA00BA" "#B200B2" "#AA00AA" "#A100A1" "#990099"
#  [92] "#910091" "#890089" "#810081" "#790079" "#710071" "#690069" "#610061"
#  [99] "#590059" "#510051"

# %% [markdown]
# **Activity 3:** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a **colorblind safe, diverging** color scheme.

# %%
library(ellipse)
head(diamonds)
data=diamonds[,c("carat","depth","price","table")]
## Your answer for activity 3 goes here ---

data <- cor(data)
ord <- order(data[1, ])
data_ord <- data[ord, ord]
plotcorr(data_ord, col=p[data_ord*50+50] , mar=c(1,1,1,1)  )
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %% [markdown]
# **Activity 4:** Create a scatter plot using **all** diamonds data for carat vs. price and encode clarity variable with a **sequential** color scheme.

# %%
## Your answer for activity 4 goes here ---
data <- diamonds[,c("carat","clarity","price")]
gp <- ggplot(data, aes(x=carat, y=price, color=clarity
                        )) + geom_point()
gp + scale_colour_brewer(type="seq", palette=1)
# Out:
# plot without title

# %% [markdown]
# **Activity 5:** Repeat Activity 4 with **alpha transparency**. **Is this a better idea? Discuss your answer.**

# %%
## Your answer for activity 5 goes here ---
data <- diamonds[,c("carat","clarity","price")]
gp <- ggplot(data, aes(x=carat, y=price, color=clarity
                        )) + geom_point(alpha=0.5)
gp + scale_colour_brewer(type="seq", palette=1)

# hint: geom_point(alpha=0.5)
# Out:
# plot without title

# %% [raw]
# This is not a better idea because it is now very difficult to see the points for diamonds with carat >2.5, and it is harder to distinguish individual points in the denser part of the graph.

# %% [markdown]
# **Activity 6:** Recreate the following plot using `ggplot2` functions and the **mtcars** data set. Hint: you may have to change attribute characteristics, also look at theme functions in `ggplot2`.
#
# <img src="ex.png">

# %%
## Your answer for activity 6 goes here ---
ggplot(mtcars, aes(x=wt, y=mpg, color=factor(cyl))) +
geom_point(aes(size=qsec, alpha = 0.5)) +
geom_smooth(method=lm, se=TRUE) +
theme_minimal()
# Out:
# plot without title
